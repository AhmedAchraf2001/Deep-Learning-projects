# %%
# !python detect.py --source ./IMG_076.jpg --weights yolov5s.pt --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=./IMG_076.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  2022-10-20 Python-3.9.7 torch-1.12.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 X:\AI\projects\Yolo\IMG_076.jpg: 640x576 1 person, 195.5ms
# Speed: 1.0ms pre-process, 195.5ms inference, 15.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp3

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("X:/AI/projects/Yolo/runs/detect/exp3/IMG_076.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()
