# %% [markdown]
# # Breast Cancer Dataset

# %%
import tensorflow as tf
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
data = load_breast_cancer()

# %%
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.33, random_state=20)

# %%
SS = StandardScaler()
X_train = SS.fit_transform(X_train)
X_test = SS.transform(X_test)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input(30),
    tf.keras.layers.Dense(40, activation= 'relu'),
    tf.keras.layers.Dense(40, activation= 'relu'),
    tf.keras.layers.Dense(20, activation= 'relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
from keras.engine.training import optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
r = model.fit(X_train, y_train, validation_data=[X_test, y_test], epochs=50)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 1s 28ms/step - loss: 0.5421 - accuracy: 0.7900 - val_loss: 0.4055 - val_accuracy: 0.9149
# Epoch 2/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3410 - accuracy: 0.9396 - val_loss: 0.2727 - val_accuracy: 0.9309
# Epoch 3/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2253 - accuracy: 0.9528 - val_loss: 0.1924 - val_accuracy: 0.9468
# Epoch 4/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1636 - accuracy: 0.9528 - val_loss: 0.1462 - val_accuracy: 0.9468
# Epoch 5/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1285 - accuracy: 0.9580 - val_loss: 0.1150 - val_accuracy: 0.9574
# Epoch 6/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1076 - accuracy: 0.9633 - val_loss: 0.0958 - val_accuracy: 0.9681
# Epoch 7/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0938 - accuracy: 0.9764 - val_loss: 0.0816 - val_accuracy: 0.9681
# Epoch 8/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0842 - accuracy: 0.9790 - val_loss: 0.0732 - val_accuracy: 0.9734
# Epoch 9/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0766 - accuracy: 0.9790 - val_loss: 0.0635 - val_accuracy: 0.9840
# Epoch 10/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0705 - accuracy: 0.9816 - val_loss: 0.0589 - val_accuracy: 0.9894
# Epoch 11/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0653 - accuracy: 0.9816 - val_loss: 0.0536 - val_accuracy: 0.9894
# Epoch 12/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0602 - accuracy: 0.9816 - val_loss: 0.0533 - val_accuracy: 0.9894
# Epoch 13/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0573 - accuracy: 0.9843 - val_loss: 0.0522 - val_accuracy: 0.9894
# Epoch 14/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0519 - accuracy: 0.9869 - val_loss: 0.0472 - val_accuracy: 0.9894
# Epoch 15/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0489 - accuracy: 0.9869 - val_loss: 0.0449 - val_accuracy: 0.9894
# Epoch 16/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0463 - accuracy: 0.9869 - val_loss: 0.0440 - val_accuracy: 0.9894
# Epoch 17/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0423 - accuracy: 0.9895 - val_loss: 0.0420 - val_accuracy: 0.9894
# Epoch 18/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0394 - accuracy: 0.9895 - val_loss: 0.0403 - val_accuracy: 0.9894
# Epoch 19/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 0.9921 - val_loss: 0.0398 - val_accuracy: 0.9894
# Epoch 20/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0335 - accuracy: 0.9921 - val_loss: 0.0381 - val_accuracy: 0.9894
# Epoch 21/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.9921 - val_loss: 0.0375 - val_accuracy: 0.9894
# Epoch 22/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0287 - accuracy: 0.9921 - val_loss: 0.0365 - val_accuracy: 0.9894
# Epoch 23/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 0.9921 - val_loss: 0.0388 - val_accuracy: 0.9894
# Epoch 24/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 0.0355 - val_accuracy: 0.9894
# Epoch 25/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9921 - val_loss: 0.0348 - val_accuracy: 0.9947
# Epoch 26/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9921 - val_loss: 0.0364 - val_accuracy: 0.9947
# Epoch 27/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 0.9921 - val_loss: 0.0343 - val_accuracy: 0.9947
# Epoch 28/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0178 - accuracy: 0.9921 - val_loss: 0.0330 - val_accuracy: 0.9947
# Epoch 29/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0166 - accuracy: 0.9921 - val_loss: 0.0351 - val_accuracy: 0.9894
# Epoch 30/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9921 - val_loss: 0.0343 - val_accuracy: 0.9894
# Epoch 31/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0138 - accuracy: 0.9948 - val_loss: 0.0345 - val_accuracy: 0.9894
# Epoch 32/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9974 - val_loss: 0.0327 - val_accuracy: 0.9894
# Epoch 33/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9948 - val_loss: 0.0332 - val_accuracy: 0.9894
# Epoch 34/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9974 - val_loss: 0.0332 - val_accuracy: 0.9894
# Epoch 35/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 0.9974 - val_loss: 0.0325 - val_accuracy: 0.9894
# Epoch 36/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9840
# Epoch 37/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0316 - val_accuracy: 0.9894
# Epoch 38/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9894
# Epoch 39/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9894
# Epoch 40/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9894
# Epoch 41/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9840
# Epoch 42/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 0.9840
# Epoch 43/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9840
# Epoch 44/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 0.9840
# Epoch 45/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9840
# Epoch 46/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0358 - val_accuracy: 0.9840
# Epoch 47/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9840
# Epoch 48/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 0.9840
# Epoch 49/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9840
# Epoch 50/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9840

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(r.history['loss'], label= 'loss')
plt.plot(r.history['val_loss'], label= 'val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label= 'accuracy')
plt.plot(r.history['val_accuracy'], label= 'val_accuracy')
plt.legend()

# %%
print('Train Score: ', model.evaluate(X_train, y_train)[1])
print('Test Score: ', model.evaluate(X_test, y_test)[1])
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Train Score:  1.0
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 0.9840
# Test Score:  0.9840425252914429
